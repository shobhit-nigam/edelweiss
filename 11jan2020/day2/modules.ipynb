# %%
import sandeep

# %%
sandeep.black()
# Out:
# dark

# %%
print(sandeep.s1)
# Out:
# 30

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/shobhit/Desktop/edel/day2',
#  '/anaconda3/lib/python37.zip',
#  '/anaconda3/lib/python3.7',
#  '/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/anaconda3/lib/python3.7/site-packages',
#  '/anaconda3/lib/python3.7/site-packages/aeosa',
#  '/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/shobhit/.ipython']

# %%
imp = """
import sandeep
from sandeep import black
from sandeep import *
import sandeep as s
from sandeep import black as b
"""

# %%
from deepak import red

# %%
red()
# Out:
# blood red

# %%
yellow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6f36898500ae> in <module>
# ----> 1 yellow()
#
# NameError: name 'yellow' is not defined

# %%
from deepak import orange

# %%
yellow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6f36898500ae> in <module>
# ----> 1 yellow()
#
# NameError: name 'yellow' is not defined

# %%
import rahul
# Out:
# hello Rahul
# naam tho suna hoga

# %%
help(rahul)
# Out:
# Help on module rahul:
#
# NAME
#     rahul - this is to demonstrate.....
#
# FUNCTIONS
#     blue()
#
#     brown()
#
# FILE
#     /Users/shobhit/Desktop/edel/day2/rahul.py

# %%
help(sandeep)
# Out:
# Help on module sandeep:
#
# NAME
#     sandeep - # coding: utf-8
#
# FUNCTIONS
#     black()
#
#     white()
#
# DATA
#     s1 = 30
#     s2 = 40
#
# FILE
#     /Users/shobhit/Desktop/edel/day2/sandeep.py

# %%
import sandeep

# %%
sandeep.grey()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b4e5efc12ca4> in <module>
# ----> 1 sandeep.grey()
#
# AttributeError: module 'sandeep' has no attribute 'grey'

# %%
import importlib

# %%
importlib.reload(sandeep)
# Out:
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# blood red
# ...

# %%
import importlib
importlib.reload(sandeep)
# Out:
# <module 'sandeep' from '/Users/shobhit/Desktop/edel/day2/sandeep.py'>

# %%
sandeep.grey()
# Out:
# dark
# bright

# %%
import bala
# Out:
# hello bala

# %%
bala.balakrishna()
# Out:
# bala bala bala
